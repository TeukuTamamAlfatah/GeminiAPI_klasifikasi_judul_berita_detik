# %%
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import string
import nltk
import seaborn as sns
from collections import Counter
from gensim.models import Word2Vec
import numpy as np
from imblearn.over_sampling import RandomOverSampler
from nltk.corpus import stopwords

# %%
df = pd.read_csv('label_data/Data_April_2024.csv')

# %%
df
# Out:
#                                            Judul Berita    Label
# 0     \nPerpanjangan Kontrak Vale 20 Tahun di RI Dip...  Positif
# 1     \nAntisipasi Mudik Lebaran, Pertamina Siapkan ...  Positif
# 2     \nVale Garap 3 Proyek Nikel di Sulawesi, Smelt...  Positif
# 3       \nPemantauan Kesiapan Stok BBM Jelang Lebaran\n   Netral
# 4     \nBocoran Hasil Pertemuan Bos Besar Freeport d...   Netral
# ...                                                 ...      ...
# 2446  \nIsi Pertemuan PM Singapura dengan Jokowi dan...   Netral
# 2447  \nViral Bea Masuk Barang Tinggi, Komisi XI DPR...  Negatif
# 2448  \nBahlil Sebut Sukanto Tanoto Investasi di IKN...  Positif
# 2449  \nAkhir Kehebohan Alat Belajar SLB yang Viral ...  Negatif
# 2450  \nRencana Freeport Nambang di Papua sampai 206...  Positif
#
# [2451 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2451 entries, 0 to 2450
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Judul Berita  2451 non-null   object
#  1   Label         2451 non-null   object
# dtypes: object(2)
# memory usage: 38.4+ KB

# %%
df.rename(columns={'Judul Berita': 'Judul_Berita'}, inplace=True)

# %%
def clean_Content(Judul_Berita):
    Judul_Berita=re.sub('@[A-Za-z0-9]+','',Judul_Berita) #menghapus @
    Judul_Berita=re.sub(r'(?:\@|http?\://|https?\://|www)\S+','',Judul_Berita) #remove link http
    Judul_Berita=' '.join(Judul_Berita.split())
    return Judul_Berita

# %%
def clean_label(Label):
    Label=re.sub('@[A-Za-z0-9]+','',Label) #menghapus @
    Label=re.sub(r'(?:\@|http?\://|https?\://|www)\S+','',Label) #remove link http
    Label=' '.join(Label.split())
    return Label

# %%
def noise_removal(words):
    words=words.translate(str.maketrans('','',string.punctuation+string.digits)) #maketrans untuk memetakan atau mengganti nilai
    words=words.strip()
    return words

# %%
data=df.copy()

# %%
data['Judul_Berita']=data['Judul_Berita'].apply(clean_Content)
data['Judul_Berita']=data['Judul_Berita'].apply(lambda x: re.sub('RT USER|USER','',x))

# %%
data['Label']=data['Label'].apply(clean_label)
data['Label']=data['Label'].apply(lambda x: re.sub('RT USER|USER','',x))

# %%
data['Judul_Berita']=data['Judul_Berita'].str.lower()
data['Judul_Berita']=data['Judul_Berita'].apply(noise_removal)

# %%
data['Label']=data['Label'].str.lower()
data['Label']=data['Label'].apply(noise_removal)

# %%
data.head()
# Out:
#                                         Judul_Berita    Label
# 0  perpanjangan kontrak vale  tahun di ri diprose...  positif
# 1  antisipasi mudik lebaran pertamina siapkan spb...  positif
# 2  vale garap  proyek nikel di sulawesi smelter r...  positif
# 3        pemantauan kesiapan stok bbm jelang lebaran   netral
# 4  bocoran hasil pertemuan bos besar freeport den...   netral

# %%
data.Label.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Label'>

# %%
# Menghitung frekuensi masing-masing label
data.Label.value_counts()
# Out:
# Label
# netral     943
# negatif    769
# positif    739
# Name: count, dtype: int64

# %%
def tokenisasi(words):
    return word_tokenize(words)

# %%
data['Judul_clean'] = data.Judul_Berita.apply(tokenisasi)

# %%
data
# Out:
#                                            Judul_Berita    Label  \
# 0     perpanjangan kontrak vale  tahun di ri diprose...  positif
# 1     antisipasi mudik lebaran pertamina siapkan spb...  positif
# 2     vale garap  proyek nikel di sulawesi smelter r...  positif
# 3           pemantauan kesiapan stok bbm jelang lebaran   netral
# 4     bocoran hasil pertemuan bos besar freeport den...   netral
# ...                                                 ...      ...
# 2446  isi pertemuan pm singapura dengan jokowi dan p...   netral
# 2447  viral bea masuk barang tinggi komisi xi dpr ak...  negatif
# 2448  bahlil sebut sukanto tanoto investasi di ikn t...  positif
# 2449  akhir kehebohan alat belajar slb yang viral di...  negatif
# 2450  rencana freeport nambang di papua sampai  baka...  positif
#
#                                             Judul_clean
# 0     [perpanjangan, kontrak, vale, tahun, di, ri, d...
# 1     [antisipasi, mudik, lebaran, pertamina, siapka...
# 2     [vale, garap, proyek, nikel, di, sulawesi, sme...
# 3     [pemantauan, kesiapan, stok, bbm, jelang, leba...
# 4     [bocoran, hasil, pertemuan, bos, besar, freepo...
# ...                                                 ...
# 2446  [isi, pertemuan, pm, singapura, dengan, jokowi...
# 2447  [viral, bea, masuk, barang, tinggi, komisi, xi...
# 2448  [bahlil, sebut, sukanto, tanoto, investasi, di...
# 2449  [akhir, kehebohan, alat, belajar, slb, yang, v...
# 2450  [rencana, freeport, nambang, di, papua, sampai...
#
# [2451 rows x 3 columns]

# %%
indo_stopword=stopwords.words('indonesian')

# %%
def stopwords_removal(words):
    return [word for word in words if word not in indo_stopword]

# %%
data['Judul_clean']=data['Judul_clean'].apply(stopwords_removal)
data.head()
# Out:
#                                         Judul_Berita    Label  \
# 0  perpanjangan kontrak vale  tahun di ri diprose...  positif
# 1  antisipasi mudik lebaran pertamina siapkan spb...  positif
# 2  vale garap  proyek nikel di sulawesi smelter r...  positif
# 3        pemantauan kesiapan stok bbm jelang lebaran   netral
# 4  bocoran hasil pertemuan bos besar freeport den...   netral
#
#                                          Judul_clean
# 0  [perpanjangan, kontrak, vale, ri, diproses, bo...
# 1  [antisipasi, mudik, lebaran, pertamina, siapka...
# 2  [vale, garap, proyek, nikel, sulawesi, smelter...
# 3  [pemantauan, kesiapan, stok, bbm, jelang, leba...
# 4  [bocoran, hasil, pertemuan, bos, freeport, jok...

# %%
def list_text(token):
    text=' '
    return text.join(token)

# %%
data.Judul_clean = data.Judul_clean.apply(list_text)

# %%
text_berita = data.Judul_clean.to_string()

# %%
wordcloud=WordCloud(background_color='white', width=1920,height=1080)
wordcloud.generate(text_berita)
plt.figure()
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# oversample = RandomOverSampler(sampling_strategy='auto', random_state=42)

# %%
# X, y = oversample.fit_resample(data[['Judul_clean']], data[['Label']])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data['Judul_clean'], data['Label'], test_size=0.2, random_state=42)

# %%
sentences = [sentence.split() for sentence in X_train]
w2v_model = Word2Vec(sentences, vector_size=100, window=5, min_count=5, workers=4)

# %%
def vectorize(sentence):
    words = sentence.split()
    words_vecs = [w2v_model.wv[word] for word in words if word in w2v_model.wv]
    if len(words_vecs) == 0:
        return np.zeros(100)
    words_vecs = np.array(words_vecs)
    return words_vecs.mean(axis=0)

X_train = np.array([vectorize(sentence) for sentence in X_train])
X_test = np.array([vectorize(sentence) for sentence in X_test])

# %%
X_train
# Out:
# array([[-0.00581744,  0.01421628,  0.00167893, ..., -0.02780207,
#          0.00809414, -0.00136687],
#        [-0.00373081,  0.00301083, -0.00085955, ..., -0.00380736,
#          0.00482354, -0.00184893],
#        [-0.00317177,  0.01132493,  0.0026005 , ..., -0.01009765,
#          0.00648913, -0.00512014],
#        ...,
#        [-0.00789773,  0.00340045,  0.00081488, ..., -0.00783661,
#          0.00036795, -0.00244319],
#        [-0.00450968,  0.01692146, -0.0058547 , ..., -0.02502989,
#          0.01036162, -0.00116944],
#        [-0.00829847,  0.01625414, -0.00261039, ..., -0.02817888,
#          0.00410917, -0.00517514]])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.multiclass import OneVsRestClassifier


# Membuat instance dari model Logistic Regression
clf_logistic = LogisticRegression()
clf_logistic.fit(X_train, y_train)

# Membuat instance dari model Naive Bayes
clf_naive_bayes = OneVsRestClassifier(GaussianNB())
clf_naive_bayes.fit(X_train, y_train)

# clf_naive_bayes = OneVsRestClassifier(MultinomialNB())
# clf_naive_bayes.fit(X_train, y_train)

# Membuat instance dari model Support Vector Machine (SVM)
clf_svm = SVC()
clf_svm.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 13
#      11 # Membuat instance dari model Naive Bayes Multinomial
#      12 clf_naive_bayes = OneVsRestClassifier(MultinomialNB())
# ---> 13 clf_naive_bayes.fit(X_train, y_train)
#      15 # Membuat instance dari model Support Vector Machine (SVM)
#      16 clf_svm = SVC()
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/sklearn/multiclass.py:330, in OneVsRestClassifier.fit(self, X, y)
#     326 columns = (col.toarray().ravel() for col in Y.T)
#     327 # In cases where individual estimators are very fast to train setting
#     328 # n_jobs > 1 in can results in slower performance due to the overhead
#     329 # of spawning threads.  See joblib issue #112.
# --> 330 self.estimators_ = Parallel(n_jobs=self.n_jobs, verbose=self.verbose)(
#     331     delayed(_fit_binary)(
#     332         self.estimator,
#     333         X,
#     334         column,
#     335         classes=[
#     336             "not %s" % self.label_binarizer_.classes_[i],
#     337             self.label_binarizer_.classes_[i],
#     338         ],
#     339     )
#     340     for i, column in enumerate(columns)
#     341 )
#     343 if hasattr(self.estimators_[0], "n_features_in_"):
#     344     self.n_features_in_ = self.estimators_[0].n_features_in_
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/joblib/parallel.py:1085, in Parallel.__call__(self, iterable)
#    1076 try:
#    1077     # Only set self._iterating to True if at least a batch
#    1078     # was dispatched. In particular this covers the edge
#    (...)
#    1082     # was very quick and its callback already dispatched all the
#    1083     # remaining jobs.
#    1084     self._iterating = False
# -> 1085     if self.dispatch_one_batch(iterator):
#    1086         self._iterating = self._original_iterator is not None
#    1088     while self.dispatch_one_batch(iterator):
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/sklearn/utils/parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/sklearn/multiclass.py:83, in _fit_binary(estimator, X, y, classes)
#      81 else:
#      82     estimator = clone(estimator)
# ---> 83     estimator.fit(X, y)
#      84 return estimator
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/sklearn/naive_bayes.py:776, in _BaseDiscreteNB.fit(self, X, y, sample_weight)
#     774 n_classes = Y.shape[1]
#     775 self._init_counters(n_classes, n_features)
# --> 776 self._count(X, Y)
#     777 alpha = self._check_alpha()
#     778 self._update_feature_log_prob(alpha)
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/sklearn/naive_bayes.py:898, in MultinomialNB._count(self, X, Y)
#     896 def _count(self, X, Y):
#     897     """Count and smooth feature occurrences."""
# --> 898     check_non_negative(X, "MultinomialNB (input X)")
#     899     self.feature_count_ += safe_sparse_dot(Y.T, X)
#     900     self.class_count_ += Y.sum(axis=0)
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/sklearn/utils/validation.py:1418, in check_non_negative(X, whom)
#    1415     X_min = xp.min(X)
#    1417 if X_min < 0:
# -> 1418     raise ValueError("Negative values in data passed to %s" % whom)
#
# ValueError: Negative values in data passed to MultinomialNB (input X)

# %%
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

def display_classification_reports(models, X_test, y_test):
    for name, model in models.items():
        print(f"Classification Report for {name}:")
        y_pred = model.predict(X_test)
        print(classification_report(y_test, y_pred))
        print("="*50)

# Membuat dictionary untuk menyimpan nama model dan modelnya
models = {
    "Logistic Regression": clf_logistic,
    "Naive Bayes": clf_naive_bayes,
    "SVM": clf_svm
}

# Memanggil fungsi untuk menampilkan laporan klasifikasi untuk semua model
display_classification_reports(models, X_test, y_test)

# %%
y_pred = clf_naive_bayes.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
