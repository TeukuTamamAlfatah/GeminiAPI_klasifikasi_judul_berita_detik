# %% [markdown]
# # Import

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as sp
import random

# %% [markdown]
# # Scraping
# > ### Param
# > - tgl_akhir : scraping nya sampai tanggal berapa pada bulan dan tahun tertentu
# > - bulan : berita pada bulan berapa yang akan di scraping
# > - tahun : berita pada tahun berapa yang akan di scraping

# %%
def scraping(tgl_akhir, bulan, tahun):
    judul = []
    # iterasi dari tanggal 1 pada bulan yang ditentukan
    tgl = 1 
    # iterasi sampai dengan tanggal terahir yang ditentukan
    while tgl <= tgl_akhir: 
        # pada tanggal tertentu iterasi dumulai dari halaman 1
        hal = 1
        # selama list_berita punya lenght ambil list_berita dari page tertentu
        while True:
            # membuat http request
            response = requests.get(f'https://finance.detik.com/indeks/{hal}?date={bulan:02d}/{tgl:02d}/{tahun}')
            response = response.text
            # mem-parsing respon HTML menggunakan parser lxml.
            parser = sp(response,'lxml')
            # ambil list berita
            list_berita = parser.select('div.grid-row.list-content')[0].find_all('article')
            # cek apakah ada list berita pada page tertentu
            if not list_berita:
                break
            # berita yang ada dalam list berita ...
            for berita in list_berita:
                # ambil judulnya
                judul.append(berita.find('h3').text)
            # print progres tiap halaman
            print(f"halaman {hal} done")
            hal += 1
        # print progres tiap tanggal
        print(f"==tanggal {tgl} done==")
        tgl += 1
    df = pd.DataFrame({
        'judul': judul
    })

    return df

# %% [markdown]
# # Panggil function

# %%
data = scraping(29, 3, 2024)
# Out:
# halaman 1 done
# halaman 2 done
# halaman 3 done
# halaman 4 done
# halaman 5 done
# halaman 6 done
# ==tanggal 1 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# halaman 4 done
# ==tanggal 2 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# ==tanggal 3 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# halaman 4 done
# halaman 5 done
# halaman 6 done
# halaman 7 done
# ==tanggal 4 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# halaman 4 done
# halaman 5 done
# halaman 6 done
# ==tanggal 5 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# halaman 4 done
# halaman 5 done
# halaman 6 done
# ==tanggal 6 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# halaman 4 done
# halaman 5 done
# halaman 6 done
# halaman 7 done
# ==tanggal 7 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# halaman 4 done
# halaman 5 done
# halaman 6 done
# ==tanggal 8 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# ==tanggal 9 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# ==tanggal 10 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# ==tanggal 11 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# ==tanggal 12 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# halaman 4 done
# halaman 5 done
# halaman 6 done
# halaman 7 done
# ==tanggal 13 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# halaman 4 done
# halaman 5 done
# halaman 6 done
# halaman 7 done
# ==tanggal 14 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# halaman 4 done
# halaman 5 done
# halaman 6 done
# ==tanggal 15 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# halaman 4 done
# ==tanggal 16 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# ==tanggal 17 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# halaman 4 done
# halaman 5 done
# halaman 6 done
# halaman 7 done
# halaman 8 done
# ==tanggal 18 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# halaman 4 done
# halaman 5 done
# halaman 6 done
# halaman 7 done
# ==tanggal 19 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# halaman 4 done
# halaman 5 done
# halaman 6 done
# ==tanggal 20 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# halaman 4 done
# halaman 5 done
# halaman 6 done
# halaman 7 done
# ==tanggal 21 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# halaman 4 done
# halaman 5 done
# halaman 6 done
# ==tanggal 22 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# halaman 4 done
# ==tanggal 23 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# ==tanggal 24 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# halaman 4 done
# halaman 5 done
# halaman 6 done
# ==tanggal 25 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# halaman 4 done
# halaman 5 done
# halaman 6 done
# ==tanggal 26 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# halaman 4 done
# halaman 5 done
# halaman 6 done
# halaman 7 done
# ==tanggal 27 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# halaman 4 done
# halaman 5 done
# halaman 6 done
# halaman 7 done
# ==tanggal 28 done==
# halaman 1 done
# halaman 2 done
# halaman 3 done
# halaman 4 done
# ==tanggal 29 done==

# %% [markdown]
# # Hasil

# %%
data.head()
# Out:
#                                                judul
# 0         \nOperasi Pasar Beras Murah Jelang Puasa\n
# 1  \nJokowi Ungkap Ekspor Nikel Tembus Rp 500 T U...
# 2  \nMinta Presiden Baru Hati-hati Kelola Ekonomi...
# 3  \nJokowi Sebut Smelter Freeport Beroperasi Jun...
# 4  \nCatatan Kredit Jelek, Bagaimana Cara Members...

# %%
data.judul[1]
# Out:
# '\nJokowi Ungkap Ekspor Nikel Tembus Rp 500 T Usai Hilirisasi, Dulu Rp 30 T\n'

# %% [markdown]
# # Simpang ke format .csv

# %%
data.to_csv('data/maret_2024.csv', index=False, encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data.to_csv('data/maret_2024.csv', index=False, encoding='utf-8')
#
# NameError: name 'data' is not defined
